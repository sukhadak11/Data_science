# %% [markdown]
# 1. Create a list of 5 integers. Perform and print the result of the following operations:
#    append, extend, insert, remove, pop, clear, index, count, sort, and reverse.

# %%
the_list = [2,3,4,6,7]
the_list
# Out:
# [2, 3, 4, 6, 7]

# %%
# Append operation
the_list.append(9)
the_list
# Out:
# [2, 3, 4, 6, 7, 9]

# %%
# Extend Operation
my_list = [1,5]
my_list
# Out:
# [1, 5]

# %%
the_list.extend(my_list)
the_list
# Out:
# [2, 3, 4, 6, 7, 9, 1, 5]

# %%
the_list.insert(3,10)
the_list
# Out:
# [2, 3, 4, 10, 6, 7, 9, 1, 5]

# %%
the_list.remove(4)
the_list
# Out:
# [2, 3, 10, 6, 7, 9, 1, 5]

# %%
the_list.pop()
the_list
# Out:
# [2, 3, 10, 6, 7, 9, 1]

# %%
the_list[0]
# Out:
# 2

# %%
the_list[1:4]
# Out:
# [3, 10, 6]

# %%
the_list.count(3)
# Out:
# 1

# %%
the_list.sort()

# %%
the_list
# Out:
# [1, 2, 3, 6, 7, 9, 10]

# %%
the_list.reverse()

# %%
the_list
# Out:
# [10, 9, 7, 6, 3, 2, 1]

# %%
the_list.clear()
the_list
# Out:
# []

# %% [markdown]
# 2.Create a tuple that stores 3 student names. Try changing the second name in the tuple. What happens? Explain why

# %%
students = ("Sukhada", "Shweta", "Parth")
print(students)
# Out:
# ('Sukhada', 'Shweta', 'Parth')

# %%
students[1] = "Sarvesh"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[18], line 1
# ----> 1 students[1] = "Sarvesh"
#
# TypeError: 'tuple' object does not support item assignment

# %% [markdown]
# Explanation:
# - Tuples are immutable in Python.
# - That means once a tuple is created, you cannot change, add, or remove elements directly.
# - Trying to modify any element will result in a TypeError.

# %%
temp_list = list(students)
temp_list[1] = "Sarvesh"
students = tuple(temp_list)
print(students)
# Out:
# ('Sukhada', 'Sarvesh', 'Parth')

# %% [markdown]
# 3. Create a set of integers with some duplicate values. Print the set and explain the output.

# %%
my_set = {1: 20, 2: 40, 3: 60, 4: 20, 5: 40, 6: 20, 7: 60}
my_set
# Out:
# {1: 20, 2: 40, 3: 60, 4: 20, 5: 40, 6: 20, 7: 60}

# %% [markdown]
# Explanation of Output
#
# A dictionary in Python stores data as key: value pairs.
#
# In your case:
#
# - Keys = 1, 2, 3, 4, 5, 6, 7
#
# - Values = 20, 40, 60, 20, 40, 20, 60
#
# So the dictionary means:
#
# - Key 1 maps to value 20
#
# - Key 2 maps to value 40
#
# - Key 3 maps to value 60
#
# - Key 4 maps to value 20
#
# - Key 5 maps to value 40
#
# - Key 6 maps to value 20
#
# - Key 7 maps to value 60

# %% [markdown]
# 4. Create a dictionary with the keys: 'name', 'age', and 'city'. Update the age and add a new key 'email'. Print the final dictionary.

# %%
detail = {"name":"Sukhada", "age": 22, "city": "Nanded"}
detail
# Out:
# {'name': 'Sukhada', 'age': 22, 'city': 'Nanded'}

# %%
detail["age"] = 21
detail
# Out:
# {'name': 'Sukhada', 'age': 21, 'city': 'Nanded'}

# %%
detail["email"] = "sk@gmail.com"

# %%
print(detail)
# Out:
# {'name': 'Sukhada', 'age': 21, 'city': 'Nanded', 'email': 'sk@gmail.com'}

# %% [markdown]
# 5.Write a script that checks if a person is eligible to vote (age ≥ 18). Take age as a variable and print the appropriate message

# %%
age = int(input("Enter Age:"))
if age>=18:
    print("Your are eligable for vote")
else:
    print("Your are not eligable for vote")
# Out:
# Enter Age:21
# Your are eligable for vote

# %% [markdown]
# 6.Given a 'marks' variable, print the grade:
# - 90 and above: 'A'
# - 75–89: 'B'
# - 50–74: 'C'
# - Below 50: 'Fail'

# %%
marks = int(input("Enter Marks:"))
if marks>=90:
    print("A")
elif 75<=marks>=89:
    print("B")
elif 50<=marks>=74:
    print("C")
else:
    print("Fail")
# Out:
# Enter Marks:90
# A

# %% [markdown]
# 7.Given a number, check if it's positive, and if it is also even. If not positive, print if it's zero or negative.

# %%
n = int(input())
if n>0:
    if n%2==0:
        print(f"{n} is postive and even")
    else:
        print(f"{n} is postive but negative")
elif n==0:
    print(f"{n} is zero")
else:
    print(f"{n} is negative")
# Out:
# 6
# 6 is postive and even
